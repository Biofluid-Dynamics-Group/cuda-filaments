# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import cmcrameri.cm as cmc

# %%
# Define file paths
q1_file = "../input/forcing/platy_reference_phase_generalised_forces_NSEG=20_SEP=2.600000_FEFF=0.300000_THETA0=1.495996.dat"
q2_file = "../input/forcing/platy_reference_angle_generalised_forces_NSEG=20_SEP=2.600000_FEFF=0.300000_THETA0=1.495996.dat"
n = 25000

# Read the first generalised forces function (q1)
with open(q1_file, 'r') as f:
  data = f.read().strip().split()
  forces_1 = np.array([float(val) for val in data[1:]])
  n_samples_1 = len(forces_1)

# Read the second generalised forces function (q2)
with open(q2_file, 'r') as f:
  data = f.read().strip().split()
  forces_2 = np.array([float(val) for val in data[1:]])
  n_samples_2 = len(forces_2)

# Generate evenly spaced s values from 0 to 2π
psi_values = np.linspace(0, 2*np.pi, n)

# Create figure and main axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot q1 and q2 on main axes
ax.plot(psi_values[:n_samples_1], forces_1, label=r'$q_1$', color=cmc.batlowKS(0.2))
ax.plot(psi_values[:n_samples_2], forces_2, label=r'$q_2$', color=cmc.batlowKS(0.8))
ax.set_xlabel('phase')
ax.set_ylabel('')
ax.set_title('forcing for beat C, blobs in wall')
ax.legend()
ax.grid(True)

# Create inset axes for the zoomed region
# axins = inset_axes(ax, width="40%", height="40%", loc="right")

# Plot the same data in the inset
# axins.plot(psi_values_1, forces_1, label=r'$q_1$', color=cmc.batlowKS(0.2))
# axins.plot(psi_values_2, forces_2, label=r'$q_2$', color=cmc.batlowKS(0.8))
# axins.grid(True)

# Set the limits for the zoomed region
# x_min = 0.3*2*np.pi - 0.0*0.3*2*np.pi
# x_max = 0.3*2*np.pi + 0.4*0.3*2*np.pi
# axins.set_xlim(x_min, x_max)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 44
#      42 x_min = 0.3*2*np.pi - 0.0*0.3*2*np.pi
#      43 x_max = 0.3*2*np.pi + 0.4*0.3*2*np.pi
# ---> 44 axins.set_xlim(x_min, x_max)
#      46 plt.show()
#
# NameError: name 'axins' is not defined

# %%
# Define file paths
q2_file = "../input/forcing/fulford_and_blake_reference_angle_generalised_forces_NSEG=20_SEP=2.600000.dat"
q1_file = "../input/forcing/fulford_and_blake_reference_phase_generalised_forces_NSEG=20_SEP=2.600000.dat"

# Read the first generalised forces function (q1)
with open(q1_file, 'r') as f:
  data = f.read().strip().split()
  n_samples = int(data[0])
  forces_1 = np.array([float(val) for val in data[1:]])

# Read the second generalised forces function (q2)
with open(q2_file, 'r') as f:
  data = f.read().strip().split()
  n_samples_2 = int(data[0])
  forces_2 = np.array([float(val) for val in data[1:]])

# Generate evenly spaced s values from 0 to 2π
psi_values = np.linspace(0, 2*np.pi, n_samples)

# Create figure and main axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot q1 and q2 on main axes
ax.plot(psi_values, forces_1, label=r'$q_1$', color=cmc.batlowKS(0.2))
ax.plot(psi_values, forces_2, label=r'$q_2$', color=cmc.batlowKS(0.8))
ax.set_xlabel('phase')
ax.set_ylabel('')
ax.set_title('forcing')
ax.legend()
ax.grid(True)

# Create inset axes for the zoomed region
# axins = inset_axes(ax, width="40%", height="40%", loc="right")

# # Plot the same data in the inset
# axins.plot(psi_values, forces_1, label=r'$q_1$', color=cmc.batlowKS(0.2))
# axins.plot(psi_values, forces_2, label=r'$q_2$', color=cmc.batlowKS(0.8))
# axins.grid(True)

# # Set the limits for the zoomed region
# x_min = 0.3*2*np.pi - 0.5
# x_max = 0.3*2*np.pi + 0.5
# axins.set_xlim(x_min, x_max)

plt.show()

# %%
# Define file paths
q2_file = "../build_a_beat_1.99000_0.08333_0.75000_0.05000_reference_angle_generalised_forces.dat"
q1_file = "../build_a_beat_1.99000_0.08333_0.75000_0.05000_reference_phase_generalised_forces.dat"

# Read the first generalised forces function (q1)
with open(q1_file, 'r') as f:
  data = f.read().strip().split()
  n_samples = int(data[0])
  forces_1 = np.array([float(val) for val in data[1:]])

# Read the second generalised forces function (q2)
with open(q2_file, 'r') as f:
  data = f.read().strip().split()
  n_samples_2 = int(data[0])
  forces_2 = np.array([float(val) for val in data[1:]])

# Generate evenly spaced s values from 0 to 2π
psi_values = np.linspace(0, 2*np.pi, n_samples)

# Create figure and main axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot q1 and q2 on main axes
ax.plot(psi_values, forces_1, label=r'$q_1$', color=cmc.batlowKS(0.2))
ax.plot(psi_values, forces_2, label=r'$q_2$', color=cmc.batlowKS(0.8))
ax.set_xlabel('phase')
ax.set_ylabel('')
ax.set_title('forcing')
ax.legend()
ax.grid(True)

# Create inset axes for the zoomed region
# axins = inset_axes(ax, width="40%", height="40%", loc="right")

# # Plot the same data in the inset
# axins.plot(psi_values, forces_1, label=r'$q_1$', color=cmc.batlowKS(0.2))
# axins.plot(psi_values, forces_2, label=r'$q_2$', color=cmc.batlowKS(0.8))
# axins.grid(True)

# # Set the limits for the zoomed region
# x_min = 0.3*2*np.pi - 0.5
# x_max = 0.3*2*np.pi + 0.5
# axins.set_xlim(x_min, x_max)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 6
#       3 q1_file = "../build_a_beat_1.99000_0.08333_0.75000_0.05000_reference_phase_generalised_forces.dat"
#       5 # Read the first generalised forces function (q1)
# ----> 6 with open(q1_file, 'r') as f:
#       7   data = f.read().strip().split()
#       8   n_samples = int(data[0])
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../build_a_beat_1.99000_0.08333_0.75000_0.05000_reference_phase_generalised_forces.dat'
