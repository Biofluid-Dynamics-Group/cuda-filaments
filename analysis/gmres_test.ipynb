# %%
import numpy as np

path = '../data/gmres_test_e_8/20250402/ciliate_1fil_9000blob_8.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

import matplotlib.pyplot as plt

# Load data from file
data = np.loadtxt(path)

# Extract time, phase1 and phase2
time = data[:, 0]
phase1 = data[:, 2]
phase2 = data[:, 3]

# Create plot
plt.figure(figsize=(10, 6))
# plt.plot(time, phase1, label='Phase 1')
plt.plot(time, phase2, label='Phase 2')
plt.xlabel('Time')
plt.ylabel('Phase')
plt.title('Phase 1 and Phase 2 vs Time')
plt.legend()
plt.grid(True)
plt.show()
