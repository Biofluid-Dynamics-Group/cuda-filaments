# %%
try:
    from plotting_functions import *
    print("✓ Import successful!")
    print("Available functions:")
    import plotting_functions
    funcs = [name for name in dir(plotting_functions) if not name.startswith('_')]
    for func in funcs:
        print(f"  - {func}")
except ImportError as e:
    print(f"✗ Import failed: {e}")
# Out:
# ✓ Import successful!
# Available functions:
#   - Any
#   - DEFAULT_CMAP
#   - Dict
#   - FFMpegWriter
#   - FuncAnimation
#   - GapInfo
#   - Optional
#   - Path
#   - SimulationData
#   - Tuple
#   - WaveDirectionResult
#   - analyze_wave_direction
#   - annotations
#   - cmc
#   - dataclass
#   - detect_gaps
#   - load_simulation
#   - make_topdown_video
#   - math
#   - mcolors
#   - np
#   - os
#   - plot_basal_positions
#   - plot_frame
#   - plot_gap_analysis
#   - plot_kymograph
#   - plt
#   - quick_all
#   - re

# %%
base_path = "../data/cell_gaps_0/20250922/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift"
plot_basal_positions(base_path, color_by="azimuth")
# Out:
# [warn] No num_steps provided, using simple 0-1 time normalization
# [warn] Expected 696 basal entries, found 348; proceeding with file value.
# [info] Saved basal positions to analysis_output/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_basal_azimuth.png
# (<Figure size 800x800 with 2 Axes>,
#  <Axes: title={'center': 'Basal positions (N=348)'}, xlabel='x', ylabel='y'>,
#  GapInfo(has_gap=False, largest_gap_width=0.01807055101942545, largest_gap_indices=(347, 0), median_spacing=0.01805509967640373, ratio=1.0008557882979685))

# %%
base_path = "../data/cell_gaps_1/20250922/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift"
plot_basal_positions(base_path, color_by="azimuth")
# Out:
# [warn] No num_steps provided, using simple 0-1 time normalization
# [warn] Expected 696 basal entries, found 348; proceeding with file value.
# [info] Saved basal positions to analysis_output/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_basal_azimuth.png
# (<Figure size 800x800 with 2 Axes>,
#  <Axes: title={'center': 'Basal positions (N=348)'}, xlabel='x', ylabel='y'>,
#  GapInfo(has_gap=False, largest_gap_width=0.01807055101942545, largest_gap_indices=(347, 0), median_spacing=0.01805509967640373, ratio=1.0008557882979685))

# %%
base_path = "../data/cell_gaps_2/20250922/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift"
plot_basal_positions(base_path, color_by="azimuth")
# Out:
# [warn] No num_steps provided, using simple 0-1 time normalization
# [warn] Expected 696 basal entries, found 348; proceeding with file value.
# [info] Saved basal positions to analysis_output/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_basal_azimuth.png
# (<Figure size 800x800 with 2 Axes>,
#  <Axes: title={'center': 'Basal positions (N=348)'}, xlabel='x', ylabel='y'>,
#  GapInfo(has_gap=False, largest_gap_width=0.01807055101942545, largest_gap_indices=(347, 0), median_spacing=0.01805509967640373, ratio=1.0008557882979685))

# %%
base_path = '../data/cell_gaps_notilt_0/20250922/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.0000tilt_0.3000f_eff_1.4960theta0_0.0000freqshift'
plot_basal_positions(base_path, color_by="azimuth")
# Out:
# [warn] No num_steps provided, using simple 0-1 time normalization
# [warn] Expected 696 basal entries, found 348; proceeding with file value.
# [info] Saved basal positions to analysis_output/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.0000tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_basal_azimuth.png
# (<Figure size 800x800 with 2 Axes>,
#  <Axes: title={'center': 'Basal positions (N=348)'}, xlabel='x', ylabel='y'>,
#  GapInfo(has_gap=False, largest_gap_width=0.01807055101942545, largest_gap_indices=(347, 0), median_spacing=0.01805509967640373, ratio=1.0008557882979685))

# %%
base_path = '../data/cell_gaps_notilt_1/20250922/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.0000tilt_0.3000f_eff_1.4960theta0_0.0000freqshift'
plot_basal_positions(base_path, color_by="azimuth")
# Out:
# [warn] No num_steps provided, using simple 0-1 time normalization
# [warn] Expected 696 basal entries, found 348; proceeding with file value.
# [info] Saved basal positions to analysis_output/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.0000tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_basal_azimuth.png
# (<Figure size 800x800 with 2 Axes>,
#  <Axes: title={'center': 'Basal positions (N=348)'}, xlabel='x', ylabel='y'>,
#  GapInfo(has_gap=False, largest_gap_width=0.01807055101942545, largest_gap_indices=(347, 0), median_spacing=0.01805509967640373, ratio=1.0008557882979685))

# %%
base_path = '../data/cell_gaps_notilt_2/20250922/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.0000tilt_0.3000f_eff_1.4960theta0_0.0000freqshift'
plot_basal_positions(base_path, color_by="azimuth")
# Out:
# [warn] No num_steps provided, using simple 0-1 time normalization
# [warn] Expected 696 basal entries, found 348; proceeding with file value.
# [info] Saved basal positions to analysis_output/ciliate_348fil_23302blob_8.00R_0.1500torsion_0.0000tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_basal_azimuth.png
# (<Figure size 800x800 with 2 Axes>,
#  <Axes: title={'center': 'Basal positions (N=348)'}, xlabel='x', ylabel='y'>,
#  GapInfo(has_gap=False, largest_gap_width=0.01807055101942545, largest_gap_indices=(347, 0), median_spacing=0.01805509967640373, ratio=1.0008557882979685))
