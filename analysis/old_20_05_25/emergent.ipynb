# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Define file paths
q1_file = "../input/forcing/platy_reference_phase_generalised_forces_NSEG=20_SEP=2.600000_FEFF=0.300000_THETA0=1.495996.dat"
q2_file = "../input/forcing/platy_reference_angle_generalised_forces_NSEG=20_SEP=2.600000_FEFF=0.300000_THETA0=1.495996.dat"

# Read the first generalised forces function (q1)
with open(q1_file, 'r') as f:
  data = f.read().strip().split()
  n_samples = int(data[0])
  forces_1 = np.array([float(val) for val in data[1:]])

# Read the second generalised forces function (q2)
with open(q2_file, 'r') as f:
  data = f.read().strip().split()
  n_samples_2 = int(data[0])
  forces_2 = np.array([float(val) for val in data[1:]])

# Generate evenly spaced s values from 0 to 2π
psi_values = np.linspace(0, 2*np.pi, n_samples)

# Create figure and main axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot q1 and q2 on main axes
# ax.plot(psi_values, forces_1, label=r'$q_1$')
ax.plot(psi_values, forces_2, label=r'$q_2$')
ax.set_xlabel('phase')
ax.set_ylabel('')
ax.set_title('forcing')
ax.legend()
ax.grid(True)

# Create inset axes for the zoomed region
axins = inset_axes(ax, width="40%", height="40%", loc="right")

# Plot the same data in the inset
# axins.plot(psi_values, forces_1, label=r'$q_1$')
axins.plot(psi_values, forces_2, label=r'$q_2$')
axins.grid(True)

# Set the limits for the zoomed region
x_min = 0.3*2*np.pi - 0.5
x_max = 0.3*2*np.pi + 0.5
axins.set_xlim(x_min, x_max)

plt.show()

# %%
path = '../data/fixed_body_emergent_rand_0/20250401/ciliate_309fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

# Load the data from the .dat file
data = np.loadtxt(path)

# Extract time values
time = data[:, 0] / 500.0  # Since i/500 is time

# Extract psi1 values for all cilia (columns 2 to 2+309-1)
psi1_values = data[:, 2:2+309]

# Create a figure and axes
plt.figure(figsize=(12, 6))

# Plot each psi1 value over time without a legend
for i in range(psi1_values.shape[1]):
  plt.plot(time[:200], psi1_values[:200, i])

plt.xlabel('Time')
plt.ylabel('psi1 values')
plt.title('Phase of Cilia (psi1) over Time')

plt.tight_layout()
plt.show()

# %%
path = '../data/sphere_one_cilium_no_elas/20250407/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

# Load the data from the .dat file
data = np.loadtxt(path)

# Extract time values
time = data[:, 0] / 500.0  # Since i/500 is time

# Extract psi1 values
psi1_values = data[:, 2]

# Create a figure and axes
plt.figure(figsize=(12, 6))

# Plot each psi1 value over time without a legend
plt.plot(time[:], psi1_values[:])

plt.xlabel('t/T')
plt.ylabel('Phase')
plt.title('evolution of one cilium on a sphere without elasticity (tol = 1e-7)')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


path = '../data/sphere_one_cilium_no_elas/20250403/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

# Load the data from the .dat file
data = np.loadtxt(path)

# Extract time values
time = data[:, 0] / 500.0  # Since i/500 is time

# Extract psi1 values
psi1_values = data[:, 2]

# Create a figure and axes
plt.figure(figsize=(12, 6))

# Plot each psi1 value over time without a legend
plt.plot(time[:], psi1_values[:])

plt.xlabel('t/T')
plt.ylabel('Phase')
plt.title('evolution of one cilium on a sphere without elasticity (tol = 1e-8)')

plt.tight_layout()
plt.show()

# %%
# Define the two data paths
path_tol_1e7 = '../data/sphere_one_cilium_no_elas/20250407/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'
path_tol_1e8 = '../data/sphere_one_cilium_no_elas/20250403/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'
path_tol_1e6 = '../data/sphere_one_cilium_no_elas_e_6/20250408/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'
# path_tol_1e5 = '../data/sphere_one_cilium_no_elas_e_5/20250408/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'
path_tol_1e4 = '../data/sphere_one_cilium_no_elas_e_4/20250408/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

# Load data for tolerance 1e-7
data_tol_1e7 = np.loadtxt(path_tol_1e7)
time_tol_1e7 = data_tol_1e7[:, 0] / 500.0
psi1_tol_1e7 = data_tol_1e7[:, 2]

# Load data for tolerance 1e-8
data_tol_1e8 = np.loadtxt(path_tol_1e8)
time_tol_1e8 = data_tol_1e8[:, 0] / 500.0
psi1_tol_1e8 = data_tol_1e8[:, 2]

# Load data for tolerance 1e-6
data_tol_1e6 = np.loadtxt(path_tol_1e6)
time_tol_1e6 = data_tol_1e6[:, 0] / 500.0
psi1_tol_1e6 = data_tol_1e6[:, 2]

# # Load data for tolerance 1e-5
# data_tol_1e5 = np.loadtxt(path_tol_1e5)
# time_tol_1e5 = data_tol_1e5[:, 0] / 500.0
# psi1_tol_1e5 = data_tol_1e5[:, 2]

# Load data for tolerance 1e-4
data_tol_1e4 = np.loadtxt(path_tol_1e4)
time_tol_1e4 = data_tol_1e4[:, 0] / 500.0
psi1_tol_1e4 = data_tol_1e4[:, 2]

# Create a single figure with both plots
plt.figure(figsize=(12, 6))
plt.plot(time_tol_1e7, psi1_tol_1e7, label='tol = 1e-7', linestyle='--')
plt.plot(time_tol_1e8, psi1_tol_1e8, label='tol = 1e-8', linestyle='-.')
plt.plot(time_tol_1e6, psi1_tol_1e6, label='tol = 1e-6', linestyle='-')
# plt.plot(time_tol_1e5, psi1_tol_1e5, label='tol = 1e-5', linewidth=2)
plt.plot(time_tol_1e4, psi1_tol_1e4, label='tol = 1e-4', linestyle=':')

plt.xlabel('t/T')
plt.ylabel('phase')
plt.title('phase evolution of one cilium on a sphere without elasticity')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
path_1_c = '../data/sphere_one_cilium_elas_e_5/20250410/ciliate_1fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

data = np.loadtxt(path_1_c)
time = data[:, 0] / 500.0
psi1 = np.mod(data[:, 2], 2*np.pi)
psi2 = data[:, 3]

# Create a single figure with both plots
plt.figure(figsize=(12, 6))
plt.plot(time, psi1, label='psi 1', linestyle='--')
plt.plot(time, psi2, label='psi 2', linestyle='--')

plt.xlabel('t/T')
plt.ylabel('phase')
plt.title('phase evolution of one cilium on a sphere with elasticity')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
path_1_c = '../data/sphere_10_cilia_elas_e_7_leftprecon/20250506/ciliate_10fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

data = np.loadtxt(path_1_c)
time = data[:, 0] / 500.0
psi1 = np.mod(data[:, 2], 2*np.pi)
psi2 = data[:, 3]

# Create a single figure with both plots
plt.figure(figsize=(12, 6))
plt.plot(time, psi1, label='psi 1', linestyle='--')
plt.plot(time, psi2, label='psi 2', linestyle='--')

plt.xlabel('t/T')
plt.ylabel('phase')
plt.title('phase evolution of one cilium on a sphere with elasticity')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
path = '../data/sphere_309_cilia_elas_e_7_leftprecon/20250506/ciliate_309fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

# Load the data from the .dat file
data = np.loadtxt(path)

# Extract time values
time = data[:, 0] / 500.0  # Since i/500 is time

# Extract psi1 values for all cilia (columns 2 to 2+309-1)
psi1_values = data[:, 2:2+309]

# Find the index where time exceeds 0.2
# end_idx = np.argmax(time > 0.2) if np.any(time > 0.2) else len(time)
end_idx = -1

plt.figure(figsize=(12, 6))
for i in range(psi1_values.shape[1]):
  if i == 0:
    plt.plot(time[:end_idx], psi1_values[:end_idx, i])

plt.xlabel('Time')
plt.ylabel('psi1 values')
plt.title('Phase of Cilia (psi1) over Time (t <= 0.2)')
plt.tight_layout()
plt.show()

# %%
# --- Add this as a new code cell after the 309-cilia plot ---

import numpy as np
import matplotlib.pyplot as plt

# Assuming 'data' and 'time' are already loaded as in the previous cell
# and psi1_values = data[:, 2:2+309]

# Compute the Kuramoto order parameter over time
R = np.abs(np.mean(np.exp(1j * psi1_values), axis=1))

plt.figure(figsize=(10, 4))
plt.plot(time[:end_idx], R[:end_idx])
plt.xlabel('Time')
plt.ylabel('Kuramoto Order Parameter $R(t)$')
plt.title('Coordination of Cilia Over Time')
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
path_1_c = '../data/sphere_2_corrected_more_zval/20250519/ciliate_2fil_9000blob_8.00R_0.0100torsion_0.2182tilt_0.3000f_eff_1.4960theta0_0.0000freqshift_true_states.dat'

data = np.loadtxt(path_1_c)
time = data[:, 0] / 500.0
psi1 = np.mod(data[:, 2], 2*np.pi)
psi2 = data[:, 3]

# Create a single figure with both plots
plt.figure(figsize=(12, 6))
plt.plot(time, psi1, label='psi 1', linestyle='--')
# plt.plot(time, psi2, label='psi 2', linestyle='--')

plt.xlabel('t/T')
plt.ylabel('phase')
plt.title('phase evolution of one cilium on a sphere with elasticity')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
