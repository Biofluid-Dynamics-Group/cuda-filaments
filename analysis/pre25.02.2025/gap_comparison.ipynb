# %%
import numpy as np

# Define file paths for different g values
file_paths_force = {
    2.0: '../data/notiltgap_g0.0/20241115/ciliate_310fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    5.0: '../data/notiltgap_g5.0/20241111/ciliate_309fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    10.0: '../data/notiltgap_g10.0/20241111/ciliate_308fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    15.0: '../data/notiltgap_g15.0/20241115/ciliate_307fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    20.0: '../data/notiltgap_g20.0/20241111/ciliate_306fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    25.0: '../data/notiltgap_g25.0/20241111/ciliate_305fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    30.0: '../data/notiltgap_g30.0/20241115/ciliate_304fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    50.0: '../data/notiltgap_g50.0/20241114/ciliate_300fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    100.0: '../data/notiltgap_g100.0/20241114/ciliate_290fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    123.5: '../data/notiltgap_g123.5/20241109/ciliate_286fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    247.0: '../data/notiltgap_g247.0/20241109/ciliate_261fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    370.5: '../data/notiltgap_g370.5/20241109/ciliate_236fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat',
    489.1: '../data/notiltgap_g489.1/20241109/ciliate_212fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_forces.dat'
}

# Read the .dat files into NumPy arrays and store them in a dictionary
data_dict_force = {g: np.loadtxt(path) for g, path in file_paths_force.items()}

forces = {}
for g, data in data_dict_force.items():
    downstream = np.array([data[:, i:i+3] for i in range(1, 121, 6)])
    upstream = np.array([data[:, i:i+3] for i in range(-6, -121, -6)])
    print(upstream.shape, downstream.shape)
    forces[g] = {'upstream': upstream, 'downstream': downstream}
# Out:
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)

# %%
# Define file paths for different g values
file_paths_phase = {
    2.0: '../data/notiltgap_g0.0/20241115/ciliate_310fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    5.0: '../data/notiltgap_g5.0/20241111/ciliate_309fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    10.0: '../data/notiltgap_g10.0/20241111/ciliate_308fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    15.0: '../data/notiltgap_g15.0/20241115/ciliate_307fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    20.0: '../data/notiltgap_g20.0/20241111/ciliate_306fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    25.0: '../data/notiltgap_g25.0/20241111/ciliate_305fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    30.0: '../data/notiltgap_g30.0/20241115/ciliate_304fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    50.0: '../data/notiltgap_g50.0/20241114/ciliate_300fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    100.0: '../data/notiltgap_g100.0/20241114/ciliate_290fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    123.5: '../data/notiltgap_g123.5/20241109/ciliate_286fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    247.0: '../data/notiltgap_g247.0/20241109/ciliate_261fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    370.5: '../data/notiltgap_g370.5/20241109/ciliate_236fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat',
    489.1: '../data/notiltgap_g489.1/20241109/ciliate_212fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_true_states.dat'
}

# Read the .dat files into NumPy arrays and store them in a dictionary
data_dict_phase = {g: np.loadtxt(path) for g, path in file_paths_phase.items()}

phases = {}
for g, data in data_dict_phase.items():
    downstream = np.mod(data[:, 2], 2*np.pi)
    upstream = np.mod(data[:, -1], 2*np.pi)
    print(upstream.shape, downstream.shape)
    phases[g] = {'upstream': upstream, 'downstream': downstream}
# Out:
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)

# %%
# Define file paths for different g values
file_paths_vels = {
    2.0: '../data/notiltgap_g0.0/20241115/ciliate_310fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    5.0: '../data/notiltgap_g5.0/20241111/ciliate_309fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    10.0: '../data/notiltgap_g10.0/20241111/ciliate_308fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    15.0: '../data/notiltgap_g15.0/20241115/ciliate_307fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    20.0: '../data/notiltgap_g20.0/20241111/ciliate_306fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    25.0: '../data/notiltgap_g25.0/20241111/ciliate_305fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    30.0: '../data/notiltgap_g30.0/20241115/ciliate_304fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    50.0: '../data/notiltgap_g50.0/20241114/ciliate_300fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    100.0: '../data/notiltgap_g100.0/20241114/ciliate_290fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    123.5: '../data/notiltgap_g123.5/20241109/ciliate_286fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    247.0: '../data/notiltgap_g247.0/20241109/ciliate_261fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    370.5: '../data/notiltgap_g370.5/20241109/ciliate_236fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat',
    489.1: '../data/notiltgap_g489.1/20241109/ciliate_212fil_5000blob_4.00R_0.0010torsion_0.0000tilt_0.3000f_eff_1.4960theta0_seg_vels.dat'
}

# Read the .dat files into NumPy arrays and store them in a dictionary
data_dict_vels = {g: np.loadtxt(path) for g, path in file_paths_vels.items()}

velocities = {}
for g, data in data_dict_vels.items():
    downstream = np.array([data[:, i:i+3] for i in range(1, 121, 6)])
    upstream = np.array([data[:, i:i+3] for i in range(-6, -121, -6)])
    print(upstream.shape, downstream.shape)
    velocities[g] = {'upstream': upstream, 'downstream': downstream}
# Out:
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)
# (20, 101, 3) (20, 101, 3)

# %%
# Initialize an empty dictionary to store the sum of dot products for each g value
viscous_dissipation_dict = {}
generalised_forces_dict = {}

# Iterate over each g value in the forces dictionary
for g in forces.keys():
    # Get the upstream and downstream forces and velocities for the current g value
    upstream_forces = forces[g]['upstream']
    downstream_forces = forces[g]['downstream']
    upstream_velocities = velocities[g]['upstream']
    downstream_velocities = velocities[g]['downstream']
    
    # Calculate the dot products for upstream and downstream
    upstream_dot_products = np.sum(np.einsum('ijk,ijk->ij', upstream_forces, upstream_velocities), axis=0)
    downstream_dot_products = np.sum(np.einsum('ijk,ijk->ij', downstream_forces, downstream_velocities), axis=0)

    print(upstream_dot_products.shape, downstream_dot_products.shape)

    
    while phases[g]['upstream'][0] > phases[g]['upstream'][-1]:
        phases[g]['upstream'] = np.roll(phases[g]['upstream'], -1)
        upstream_dot_products = np.roll(upstream_dot_products, -1)
    
    while phases[g]['downstream'][0] > phases[g]['downstream'][-1]:
        phases[g]['downstream'] = np.roll(phases[g]['downstream'], -1)
        downstream_dot_products = np.roll(downstream_dot_products, -1)
    
    viscous_dissipation_dict[g] = {'upstream': upstream_dot_products, 'downstream': downstream_dot_products}
    generalised_forces_dict[g] = {'upstream': upstream_dot_products/2/np.pi, 'downstream': downstream_dot_products/2/np.pi}
# Out:
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)
# (101,) (101,)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

plt.rcParams.update({'font.size': 20})

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Normalize the color map based on the gap sizes
norm = plt.Normalize(-max(generalised_forces_dict.keys())/2, max(generalised_forces_dict.keys())/2)

# Plot the data for each gap size
for g in sorted(generalised_forces_dict.keys(), reverse=True):

    if g == 2.0:
        color_upstream = 'black'
        color_downstream = 'black'
        alpha = 1.0
    else:
        # Get the color for the current gap size
        color_upstream = cm.coolwarm(norm(-g/2))
        color_downstream = cm.coolwarm(norm(g/2))
        alpha = 1.0
    
    if g == 489.1:
        # Plot upstream data
        ax.plot(phases[g]['upstream']/2/np.pi, generalised_forces_dict[g]['upstream'], color=color_upstream, alpha=alpha, label='upstream')
        
        # Plot downstream data
        ax.plot(phases[g]['downstream']/2/np.pi, generalised_forces_dict[g]['downstream'], color=color_downstream, alpha=alpha, label='downstream')

    if g == 2.0:
        # Plot upstream data
        ax.plot(phases[g]['upstream']/2/np.pi, generalised_forces_dict[g]['upstream'], color=color_upstream, alpha=0.8, linestyle='--', label='no  gap')

# Add labels and title
ax.set_xlabel(r'phase [$\mathrm{mod}\;2\pi$]')
ax.set_ylabel('force [$\omega_0 \mu^{-1} L^{-2}$]')
ax.set_title(r'effect of large gap ($490 \mu\mathrm{m}$) on force required along the beat')

# Create a color bar
# sm = plt.cm.ScalarMappable(cmap=cm.RdBu, norm=norm)
# sm.set_array([])
# cbar = plt.colorbar(sm, ax=ax)
# cbar.set_label(r'Relative position [$\mu\mathrm{m}$]')

# Add legend
ax.legend(loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()

plt.savefig('generalised_forces.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88430ea7941f> in <module>
#       8
#       9 # Normalize the color map based on the gap sizes
# ---> 10 norm = plt.Normalize(-max(generalised_forces_dict.keys())/2, max(generalised_forces_dict.keys())/2)
#      11
#      12 # Plot the data for each gap size
#
# NameError: name 'generalised_forces_dict' is not defined

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Normalize the color map based on the gap sizes
norm = plt.Normalize(-25.0/2, 25.0/2)

# Plot the data for each gap size
for g in sorted(generalised_forces_dict.keys(), reverse=True):

    if g == 2.0:
        color_upstream = 'black'
        color_downstream = 'black'
        alpha = 1.0
    else:
        # Get the color for the current gap size
        color_upstream = cm.coolwarm(norm(-g/2))
        color_downstream = cm.coolwarm(norm(g/2))
        alpha = 1.0
    
    if g == 25.0:
        # Plot upstream data
        ax.plot(phases[g]['upstream']/2/np.pi, generalised_forces_dict[g]['upstream'], color=color_upstream, alpha=alpha, label='upstream')
        
        # Plot downstream data
        ax.plot(phases[g]['downstream']/2/np.pi, generalised_forces_dict[g]['downstream'], color=color_downstream, alpha=alpha, label='downstream')

    if g == 2.0:
        # Plot upstream data
        ax.plot(phases[g]['upstream']/2/np.pi, generalised_forces_dict[g]['upstream'], color=color_upstream, alpha=0.8, linestyle='--', label='no  gap')

# Add labels and title
ax.set_xlabel(r'phase [$\mathrm{mod}\;2\pi$]')
ax.set_ylabel('force [$\omega_0 \mu^{-1} L^{-2}$]')
ax.set_title(r'effect of gap ($25 \mu\mathrm{m}$) on force required along the beat')

# Create a color bar
# sm = plt.cm.ScalarMappable(cmap=cm.RdBu, norm=norm)
# sm.set_array([])
# cbar = plt.colorbar(sm, ax=ax)
# cbar.set_label(r'Relative position [$\mu\mathrm{m}$]')

# Add legend
ax.legend(loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()

plt.savefig('generalised_forces.pdf')

# %%
# Initialize dictionaries to store the total viscous dissipation for each gap size
total_viscous_dissipation_upstream = {}
total_viscous_dissipation_downstream = {}

# Normalize the color map based on the gap sizes
norm = plt.Normalize(-max(generalised_forces_dict.keys())/2, max(generalised_forces_dict.keys())/2)

# Iterate over each gap size in the viscous_dissipation_dict
for g in viscous_dissipation_dict.keys():
    if g < 30:
        # Sum all values of viscous dissipation for upstream and downstream
        total_viscous_dissipation_upstream[g] = np.sum(viscous_dissipation_dict[g]['upstream'])
        total_viscous_dissipation_downstream[g] = np.sum(viscous_dissipation_dict[g]['downstream'])

# Convert the dictionaries to lists of tuples and sort them by gap size
sorted_upstream = sorted(total_viscous_dissipation_upstream.items())
sorted_downstream = sorted(total_viscous_dissipation_downstream.items())

# Extract the gap sizes and total viscous dissipation values
gap_sizes_upstream, total_dissipation_upstream = zip(*sorted_upstream)
gap_sizes_downstream, total_dissipation_downstream = zip(*sorted_downstream)

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(10, 6))

color_upstream = cm.coolwarm(norm(-g/2))
color_downstream = cm.coolwarm(norm(g/2))

# Plot the total viscous dissipation versus the gap size for upstream and downstream
ax.plot(gap_sizes_upstream, total_dissipation_upstream, label='upstream', color=color_upstream)
ax.plot(gap_sizes_downstream, total_dissipation_downstream, label='downstream', color=color_downstream)

# Add labels and title
ax.set_xlabel('Gap Size')
ax.set_ylabel('Total Viscous Dissipation')
ax.set_title('Total Viscous Dissipation vs. Gap Size (Gap Sizes < 30)')

# Add a legend
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Initialize a dictionary to store the percentage difference for each gap size
percentage_difference = {}

# Iterate over each gap size in the viscous_dissipation_dict
for g in viscous_dissipation_dict.keys():
    if g < 30:
        # Calculate the percentage difference
        upstream_dissipation = total_viscous_dissipation_upstream[g]
        downstream_dissipation = total_viscous_dissipation_downstream[g]
        percentage_difference[g] = ((downstream_dissipation - upstream_dissipation) / upstream_dissipation) * 100

# Convert the dictionary to a list of tuples and sort them by gap size
sorted_percentage_difference = sorted(percentage_difference.items())

# Extract the gap sizes and percentage difference values
gap_sizes, percentage_diff_values = zip(*sorted_percentage_difference)

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the percentage difference versus the gap size
ax.plot(gap_sizes, percentage_diff_values, color='black', linestyle='--', marker='o')

# Add labels and title
ax.set_xlabel(r'gap size [$\mu \mathrm{m}$]')
ax.set_ylabel(r'expenditure difference [%]')
ax.set_title('differences in energy expenditure through gap')

# Add a legend
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
